# %%
import tifffile
import matplotlib.pyplot as plt


image_path = "/Users/hydrablaster/Desktop/Otegui_lab/confocal_images/20X-mchH2Bxistl345-2-seedling1-transzone_overview/20X-mchH2Bxistl345-2-seedling1-transzone_overview_z01c2.tif"
image = tifffile.imread(image_path)

plt.figure(figsize=(6,6))
plt.imshow(image) 
plt.title("Fluorescence Image")
plt.axis("off")
plt.show()
